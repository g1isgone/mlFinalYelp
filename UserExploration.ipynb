# %%
# Tells matplotlib to display images inline instead of a new window
# %matplotlib inline
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np

# %%
userDf=pd.read_pickle('UserWithReviewDf.pkl')

# %%
plt.scatter(userDf['review_count'],userDf['average_stars'])

# %%
sns.regplot('review_count', 'average_stars', userDf, line_kws = {"color":"r"}, ci=None)

# %%
userDf.head()
# Out:
#         average_stars  review_count                 user_id yelping_since  \
# 588173           4.00             2  ---PLwSf5gKdIoVnyRHgBA    2015-07-31
# 941061           5.00             1  --0sXNBv6IizZXuV-nl0Aw    2013-01-09
# 48514            2.33             3  --104qdWvE99vaoIsj9ZJQ    2016-04-26
# 360197           5.00             5  --1mPJZdSY9KluaBYAGboQ    2011-07-04
# 84159            4.60            28  --2HUmLkcNHZp0xw6AMBPg    2016-07-28
#
#         AvailPct  AvailReviewCount  \
# 588173  1.000000                 2
# 941061  1.000000                 1
# 48514   1.000000                 3
# 360197  1.000000                 5
# 84159   0.857143                24
#
#                                                   Reviews
# 588173   {5Y_hKqpo4wb1pPtFgtCqrA, QXzgdKOdmrccxZ60Er7gig}
# 941061                           {SkVD3fpE21mwrOcZ_xFWNQ}
# 48514   {aEVdlRF69hCcNBM-aIAo1A, -8Ec71BpqD6R74VNB84u7...
# 360197  {4WNpzZjcQ5Z7PPBk_hqqEw, 1C9Pyn2AMNN0XSTOBPGzI...
# 84159   {qVO0E3qXBuol3qaryVBlhw, T3QcvFBPGjGrxEf0cT6vV...
