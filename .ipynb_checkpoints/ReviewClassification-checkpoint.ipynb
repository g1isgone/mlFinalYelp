# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Part I: Train classifiers
# ### Split data into train set and test set

# %%
trainDf=pd.read_pickle('train.pkl')

# %% [markdown]
# 1 means the user is active, and 0 means the user is inactive.

# %%
trainDf.head()
# Out:
#                     business_id        date               review_id  stars  \
# 467878   IZI9BdElfGB-WcHpd7Wg7Q  2014-02-20  CPj_ZWalJpnebGrFxV8ujg      5
# 450196   Ja4stXdNYr39u5CZHMNtjw  2012-05-14  S1EKSngF9LVvFQ08Pye59Q      4
# 1295251  bjllusUsLq9zE4yZnLpOzg  2015-09-19  9ndOEDaRsYjETx0kl83h7w      3
# 379392   QdbwZGnBWdkdN2XAG7rwLA  2014-08-15  raKjAf09z4FtAqmqfb5lUw      5
# 564809   WKOUTdVJS58E178JjhwidQ  2016-01-10  DQGL9V4vhF7wNBdVRcZ1VQ      4
#
#                                                       text  \
# 467878   Came here for a late lunch after being slightl...
# 450196   What a cute little place in Old Town!  We went...
# 1295251  Food was better than average. We got three dif...
# 379392   Korean Style Fried Chicken has become the only...
# 564809   Cute little cafe, the crepe was so good. I tri...
#
#                         user_id  active
# 467878   PTcKYk_qU-WzbQjraE3TgQ       1
# 450196   l5x4wzz9VOcQ22XMthU6uw       1
# 1295251  76crp1vXF1A3LOoNP6zcUQ       1
# 379392   4KbUaerUBoiUwZGMHKVFxQ       1
# 564809   XrYTMhY9YJvzX2pMepIz7A       1

# %%
trainDf.shape
# Out:
# (339700, 7)

# %%
X_train=trainDf['text'].values

# %%
Y_train=trainDf['active'].values

# %%
testDf=pd.read_pickle('test.pkl')

# %%
testDf.head()
# Out:
#                     business_id        date               review_id  stars  \
# 840771   LbyCngxEveE7G6w2mqeueg  2015-10-12  PhBoxX0S_htKMGweVmA7iA      4
# 524329   5N8R7ALESZ30EoAzVJtabw  2015-11-26  2ZLg2o_yh3pvXnQhdnBCFg      4
# 1022586  hPO2di89hgfsD9inbKl7BQ  2014-12-03  z48GmttobtQ28hmKChpSRQ      4
# 795885   5B-V6vr6TbtMjrRaBAtHqQ  2012-09-27  Y8jWjRX69baonQSXKLtPHg      2
# 769454   u-SJ5QUwrNquL9VnXwl8cg  2013-08-08  UnZirwkho6bJkffEhSWlug      1
#
#                                                       text  \
# 840771   Delicious old school pizza, only deliver in a ...
# 524329   Probably like a lot of you that reviewed your ...
# 1022586  This Ulta has greatly improved! The customer s...
# 795885   Not my favorite place to go, but I've only bee...
# 769454   I try to like you Postinos, I really do but yo...
#
#                         user_id  active
# 840771   UGlJYHK0I7TM6yLB3Rkp2w       1
# 524329   HgCv2lm-GuACRanD7bSqyA       1
# 1022586  HV5HZf7DOQHiwCtNdor2Zg       1
# 795885   CPodThzsqATG_Bc8a4an_w       1
# 769454   k6vOe0_qglL2PZlBldoKeQ       1

# %%
testDf.shape
# Out:
# (84926, 7)

# %%
X_test=testDf['text'].values
Y_test=testDf['active'].values

# %% [markdown]
# ### Tokenize traning texts and count word frequency using tf-idf
# Reference: http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vect = CountVectorizer()
X_train_counts = count_vect.fit_transform(X_train)
X_train_counts.shape
# Out:
# (339700, 180431)

# %%
type(X_train_counts)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
from sklearn.feature_extraction.text import TfidfTransformer
tfidf_transformer = TfidfTransformer(sublinear_tf=True)
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)
X_train_tfidf.shape
# Out:
# (339700, 180431)

# %%
X_train_tfidf
# Out:
# <339700x180431 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26478750 stored elements in Compressed Sparse Row format>

# %%
X_test_counts = count_vect.transform(X_test)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

# %% [markdown]
# ### Train a naive Bayes classifier and evaluate the performance on the test set

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(X_train_tfidf, Y_train)

# %%
predicted = clf.predict(X_test_tfidf)
np.mean(predicted == Y_test)
# Out:
# 0.77591079292560583

# %% [markdown]
# We achieve 77.6% accuracy. Not bad!
#
# ### Train a linear support vector machine (SVM) model and evalute the performance on the test set

# %%
from sklearn.linear_model import SGDClassifier
svm_clf = SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42,max_iter=5, tol=None).fit(X_train_tfidf, Y_train)

# %%
svm_clf.coef_
# Out:
# array([[-0.10526299, -0.04814701, -0.00158775, ..., -0.00067528,
#         -0.00071631, -0.0008268 ]])

# %%
svm_predicted = svm_clf.predict(X_test_tfidf)

# %%
np.mean(svm_predicted == Y_test)
# Out:
# 0.80533641052210159

# %%
from sklearn import metrics
print(metrics.classification_report(Y_test, svm_predicted,target_names=['inactive','active']))
# Out:
#              precision    recall  f1-score   support
#
#    inactive       0.80      0.82      0.81     42811
#      active       0.81      0.79      0.80     42115
#
# avg / total       0.81      0.81      0.81     84926

# %% [markdown]
# #### SVM is able to predict whether a use in the test set is active by analyzing the contents of the review with an accuracy of 80%.

# %% [markdown]
# ### Parameter tuning using grid search

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'alpha': (1e-2, 1e-3)}
gs_clf = GridSearchCV(svm_clf, parameters)

# %%
gs_clf.fit(X_train_counts, Y_train)
# Out:
# GridSearchCV(cv=None, error_score='raise',
#        estimator=SGDClassifier(alpha=0.001, average=False, class_weight=None, epsilon=0.1,
#        eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#        learning_rate='optimal', loss='hinge', max_iter=5, n_iter=None,
#        n_jobs=1, penalty='l2', power_t=0.5, random_state=42, shuffle=True,
#        tol=None, verbose=0, warm_start=False),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'alpha': (0.01, 0.001)}, pre_dispatch='2*n_jobs',
#        refit=True, return_train_score='warn', scoring=None, verbose=0)

# %%
gs_clf.best_params_
# Out:
# {'alpha': 0.01}

# %%
gs_clf.best_score_
# Out:
# 0.826264350897851

# %% [markdown]
# After tuning the parameter, the accuracy improves to 82%

# %%
svm_clf_tuned = SGDClassifier(loss='hinge', penalty='l2',alpha=0.01, random_state=42,max_iter=5, tol=None).fit(X_train_tfidf, Y_train)

# %%
svm_predicted_tuned = svm_clf_tuned.predict(X_test_tfidf)

# %%
np.mean(svm_predicted_tuned == Y_test)
# Out:
# 0.72279396180203948

# %% [markdown]
# The new parameter doesn't increase the accuracy on the test set though, but the performance is still not too bad.

# %% [markdown]
# ## Part II: Visualize & Analyze the result
# Reference: https://buhrmann.github.io/tfidf-analysis.html

# %%
#holds a list of all the words in the tf-idf’s vocabulary
features=count_vect.get_feature_names()
features
# Out:
# ['00',
#  '000',
#  '0000',
#  '00000',
#  '0000000',
#  '0000000000000001',
#  '0000000003',
#  '00001',
#  '00007651',
#  '0002',
#  '0002136',
#  '0003s',
#  '0004318',
#  '0004318zz',
#  '000dollars',
#  '000hr',
#  '000iu',
#  '000km',
#  '000kms',
#  '000lbs',
#  '000mg',
#  '000miles',
#  '000s',
#  '000sf',
#  '000x',
#  '001',
#  '0015',
#  '002',
#  '003',
#  '0030',
#  '004',
#  '005',
#  '0051',
#  '006',
#  '0067',
#  '007',
#  '00719',
#  '00789',
#  '0089',
#  '009',
#  '00____',
#  '00_____',
#  '00______',
#  '00a',
#  '00am',
#  '00dlls',
#  '00dollars',
#  '00each',
#  '00eur',
#  '00for',
#  '00h',
#  '00hh',
#  '00hr',
#  '00hrs',
#  '00ish',
#  '00lb',
#  '00noon',
#  '00off',
#  '00or',
#  '00p',
#  '00pm',
#  '00pmish',
#  '00s',
#  '00tip',
#  '00uhr',
#  '01',
#  '010',
#  '0105',
#  '0109',
#  '011856',
#  '012',
#  '0131',
#  '0135',
#  '013672',
#  '014',
#  '0143',
#  '016',
#  '017',
#  '0176',
#  '019',
#  '01am',
#  '01pm',
#  '02',
#  '0200',
#  '0213',
#  '0214',
#  '0222000',
#  '0233',
#  '025',
#  '0279',
#  '0295',
#  '02am',
#  '02pm',
#  '03',
#  '030',
#  '0300',
#  '033',
#  '0330',
#  '0359',
#  '03607',
#  '0362',
#  '0368',
#  '0383',
#  '03am',
#  '03pm',
#  '03rezepte',
#  '04',
#  '040',
#  '0400',
#  '040415',
#  '041',
#  '0430',
#  '044',
#  '04am',
#  '04neue',
#  '04pm',
#  '05',
#  '050',
#  '0530',
#  '054',
#  '0540',
#  '058',
#  '0593',
#  '0598',
#  '05a',
#  '05am',
#  '05ish',
#  '05p',
#  '05pm',
#  '05rlrr1gnycu7ig',
#  '05uhr',
#  '06',
#  '0600',
#  '0609',
#  '0645',
#  '0665_03',
#  '0667',
#  '0671',
#  '0693564',
#  '06am',
#  '06pm',
#  '07',
#  '0700',
#  '070117',
#  '070130_bad_drycleaning',
#  '0711',
#  '0730',
#  '0774',
#  '0776',
#  '0784',
#  '07921',
#  '07a',
#  '07am',
#  '07gh',
#  '07uhr',
#  '08',
#  '080',
#  '0800',
#  '0800h',
#  '0803',
#  '0815',
#  '08204',
#  '0830',
#  '0844',
#  '0845',
#  '0871',
#  '08cr0148',
#  '08f',
#  '08pm',
#  '09',
#  '0900',
#  '0902',
#  '0908',
#  '091',
#  '0915',
#  '095100',
#  '099',
#  '0994',
#  '09am',
#  '09pm',
#  '0_0',
#  '0_o',
#  '0ahukewj605le4fhrahxqq1qkhvniaxkqjgoirg',
#  '0c',
#  '0cb7yb1qrswlqvmbhw3fmw',
#  '0e6',
#  '0ed',
#  '0f',
#  '0fa',
#  '0ft',
#  '0g',
#  '0grams',
#  '0h',
#  '0l',
#  '0lace',
#  '0ld',
#  '0lztz6afnpjte2aoscfdda',
#  '0mg',
#  '0my',
#  '0n',
#  '0ne',
#  '0pi',
#  '0pmwe',
#  '0pyxiw',
#  '0qkowpzlqwzzvek_ccf',
#  '0s',
#  '0star',
#  '0stars',
#  '0v3r411',
#  '0ver',
#  '0w20',
#  '0x80c8c201f65c134f',
#  '0xf995669844c9f577',
#  '0z',
#  '0z5xmsp_h54bpslgykcmha',
#  '10',
#  '100',
#  '1000',
#  '10000',
#  '100000',
#  '1000000',
#  '10000000',
#  '100000000',
#  '100000000000',
#  '1000000000000',
#  '10000000000000000',
#  '10000000000000000000',
#  '1000008076',
#  '100000x',
#  '1000034170',
#  '1000cad',
#  '1000cc',
#  '1000dollars',
#  '1000isl',
#  '1000island',
#  '1000m',
#  '1000mah',
#  '1000mg',
#  '1000s',
#  '1000sq',
#  '1000th',
#  '1000x',
#  '1001',
#  '100311691417837093929',
#  '1004',
#  '1006',
#  '100am',
#  '100c',
#  '100count',
#  '100cu',
#  '100erten',
#  '100eur',
#  '100f',
#  '100ft',
#  '100g',
#  '100gr',
#  '100grams',
#  '100grs',
#  '100hs',
#  '100ish',
#  '100k',
#  '100km',
#  '100lb',
#  '100lbs',
#  '100m',
#  '100mbps',
#  '100mg',
#  '100miles',
#  '100ml',
#  '100mph',
#  '100oz',
#  '100pct',
#  '100percent',
#  '100pk',
#  '100s',
#  '100th',
#  '100x',
#  '100xs',
#  '101',
#  '1010',
#  '10101',
#  '10108',
#  '1011',
#  '1012',
#  '101316',
#  '1015',
#  '101500',
#  '10153419944764707',
#  '1015am',
#  '1017',
#  '1019',
#  '101gb',
#  '101st',
#  '102',
#  '1020',
#  '10205415653462893',
#  '1024',
#  '1025am',
#  '1028',
#  '1029',
#  '102º',
#  '103',
#  '1030',
#  '10300',
#  '1030a',
#  '1030am',
#  '1030pm',
#  '1031',
#  '1035am',
#  '1038',
#  '104',
#  '1040',
#  '10405',
#  '1040am',
#  '10420',
#  '1043',
#  '1045',
#  '1045ish',
#  '1045pm',
#  '1046',
#  '104ml',
#  '104º',
#  '105',
#  '1050',
#  '1050pm',
#  '10520',
#  '1055',
#  '105degree',
#  '105degrees',
#  '105f',
#  '105lbs',
#  '105min',
#  '105mm',
#  '105th',
#  '106',
#  '1060',
#  '10600',
#  '10605',
#  '1061',
#  '1065',
#  '106819075532036421969',
#  '106th',
#  '107',
#  '1070',
#  '1075',
#  '10757',
#  '107f',
#  '107th',
#  '108',
#  '1080',
#  '1080i',
#  '1080pm',
#  '10824',
#  '1086',
#  '1088',
#  '108th',
#  '109',
#  '1090',
#  '1091',
#  '10938393',
#  '1095',
#  '1099',
#  '109f',
#  '10a',
#  '10am',
#  '10az',
#  '10below',
#  '10bto',
#  '10bucks',
#  '10business',
#  '10bux',
#  '10c',
#  '10cent',
#  '10chillis',
#  '10cm',
#  '10cookies',
#  '10d8c8s',
#  '10days',
#  '10dls',
#  '10dollars',
#  '10eur',
#  '10euro',
#  '10ft',
#  '10g',
#  '10gamers',
#  '10gb',
#  '10h',
#  '10h30',
#  '10hr',
#  '10hrs',
#  '10inch',
#  '10incher',
#  '10ish',
#  '10jähriges',
#  '10k',
#  '10km',
#  '10l',
#  '10lb',
#  '10lbs',
#  '10m',
#  '10mbps',
#  '10megs',
#  '10mg',
#  '10mile',
#  '10miles',
#  '10min',
#  '10mins',
#  '10minute',
#  '10minuten',
#  '10minutes',
#  '10ml',
#  '10mm',
#  '10mn',
#  '10month',
#  '10months',
#  '10mos',
#  '10mpg',
#  '10mph',
#  '10nl',
#  '10o',
#  '10oz',
#  '10p',
#  '10pc',
#  '10pcs',
#  '10person',
#  '10pg',
#  '10pieces',
#  '10plus',
#  '10pm',
#  '10point',
#  '10pp',
#  '10ppl',
#  '10random',
#  '10s',
#  '10sec',
#  '10seconds',
#  '10secs',
#  '10small',
#  '10speed',
#  '10spot',
#  '10star',
#  '10th',
#  '10usd',
#  '10w',
#  '10w30',
#  '10x',
#  '10x10',
#  '10x13',
#  '10x15',
#  '10x20',
#  '10x30',
#  '10x5',
#  '10xs',
#  '10year',
#  '10years',
#  '10yr',
#  '10yrs',
#  '10z',
#  '10チップで一時間のマッサージを受けました',
#  '11',
#  '110',
#  '1100',
#  '1100am',
#  '1100cc',
#  '1100mah',
#  '1100pm',
#  '1100s',
#  '1101',
#  '1102',
#  '1105',
#  '1106pm',
#  '1108',
#  '1109',
#  '110degree',
#  '110dg',
#  '110f',
#  '110hp',
#  '110k',
#  '110km',
#  '110l',
#  '110lb',
#  '110lbs',
#  '110mph',
#  '110pm',
#  '110th',
#  '110v',
#  '111',
#  '1110',
#  '111026625881803880071',
#  '1111',
#  '1113',
#  '1115',
#  '1116',
#  '111702275534392',
#  '1118',
#  '111am',
#  '111th',
#  '112',
#  '1120',
#  '1121',
#  '1123',
#  '1125',
#  '11251',
#  '1126pm',
#  '112715',
#  '112th',
#  '113',
#  '1130',
#  '1130am',
#  '1130gram',
#  '1130pm',
#  '113219434',
#  '1133',
#  '1134',
#  '1135am',
#  '1136',
#  '1138',
#  '1139pm',
#  '114',
#  '1140',
#  '1140am',
#  '1141',
#  '1145',
#  '1145am',
#  '1148am',
#  '1149',
#  '11495',
#  '114kg',
#  '115',
#  '1150',
#  '11500',
#  '115275104',
#  '1155',
#  '1159',
#  '115dbs',
#  '115degrees',
#  '115g',
#  '115pm',
#  '115pp',
#  '115th',
#  '116',
#  '116004',
#  '11602',
#  '11649',
#  '1165',
#  '116f',
#  '116º',
#  '117',
#  '1170',
#  '11700',
#  '1171',
#  '1177',
#  '117k',
#  '117th',
#  '118',
#  '1180',
#  '118594498310448',
#  '1189',
#  '118f',
#  '119',
#  '1195',
#  '11987',
#  '1199',
#  '119x3',
#  '11___',
#  '11a',
#  '11am',
#  '11amto',
#  '11bucks',
#  '11bux',
#  '11eur',
#  '11euro',
#  '11h',
#  '11h30',
#  '11h45',
#  '11ish',
#  '11jun14',
#  '11k',
#  '11km',
#  '11lbs',
#  '11m',
#  '11min',
#  '11mins',
#  '11mm',
#  '11month',
#  '11oz',
#  '11p',
#  '11pc',
#  '11per',
#  '11pm',
#  '11ppm',
#  '11s',
#  '11sh',
#  '11something',
#  '11th',
#  '11x11',
#  '11x13',
#  '11x17',
#  '11y',
#  '11year',
#  '11years',
#  '11yr',
#  '11yrs',
#  '12',
#  '120',
#  '1200',
#  '12000',
#  '1200pm',
#  '1202',
#  '1204',
#  '120445377980769',
#  '1205',
#  '1208',
#  '120ish',
#  '120k',
#  '120lbs',
#  '120mhz',
#  '120ml',
#  '120mph',
#  '121',
#  '1210',
#  '1210er',
#  '1211',
#  '1212',
#  '1214',
#  '1215',
#  '1219',
#  '122',
#  '1220',
#  '1221',
#  '1225',
#  '1228',
#  '123',
#  '1230',
#  '1230am',
#  '1230p',
#  '1230pm',
#  '1234',
#  '1234567890',
#  '1235',
#  '1238279',
#  '124',
#  '1240',
#  '1241',
#  '1245',
#  '1245pm',
#  '1247',
#  '125',
#  '1250',
#  '1250am',
#  '1256',
#  '125k',
#  '125lb',
#  '125lbls',
#  '125lbs',
#  '125ml',
#  '125x2',
#  '126',
#  '1261',
#  '12658',
#  '126600',
#  '1269',
#  '127',
#  '1270',
#  '12700',
#  '1275',
#  '1279',
#  '127k',
#  '127th',
#  '128',
#  '1280',
#  '1281',
#  '128gb',
#  '128i',
#  '128th',
#  '129',
#  '129298443760458',
#  '12943',
#  '1295',
#  '1295289610554955',
#  '1299',
#  '12a',
#  '12am',
#  '12c',
#  '12cents',
#  '12cookies',
#  '12ct',
#  '12eeee',
#  '12elver',
#  '12eur',
#  '12g',
#  '12h',
#  '12hr',
#  '12hrs',
#  '12in',
#  '12inch',
#  '12inches',
#  '12ish',
#  '12iz',
#  '12june16',
#  '12k',
#  '12lb',
#  '12mbs',
#  '12mg',
#  '12midnight',
#  '12mil',
#  '12miles',
#  '12min',
#  '12mins',
#  '12minutes',
#  '12ml',
#  '12mls',
#  '12mm',
#  '12mn',
#  '12months',
#  '12national',
#  '12news',
#  '12noon',
#  '12o',
#  '12oz',
#  '12p',
#  '12pc',
#  '12pcs',
#  '12pm',
#  '12pp',
#  '12ppl',
#  '12st',
#  '12th',
#  '12v',
#  '12x',
#  '12x1',
#  '12x12',
#  '12x15',
#  '12x16',
#  '12x9',
#  '12year',
#  '12yo',
#  '12yr',
#  '12yrs',
#  '13',
#  '130',
#  '1300',
#  '13000',
#  '1300s',
#  '1301',
#  '13025',
#  '130602',
#  '130am',
#  '130eur',
#  '130ish',
#  '130k',
#  '130lb',
#  '130lbs',
#  '130pm',
#  '130th',
#  '130usd',
#  '131',
#  '1310',
#  '1311',
#  '1312',
#  '1313',
#  '1315',
#  '131main',
#  '132',
#  '1320',
#  '133',
#  '1330',
#  '13302',
#  '1331',
#  '1332',
#  '1333',
#  '1336',
#  '1339',
#  '134',
#  '1345',
#  '13494309284',
#  '135',
#  '1350',
#  '1353',
#  '13560',
#  '1359',
#  '136',
#  '1360',
#  '1363',
#  '1365',
#  '13681',
#  '13699',
#  '137',
#  '137000',
#  '1370451541',
#  '13725648',
#  '1375',
#  '137th',
#  '138',
#  '13801',
#  '1386764450',
#  '1387',
#  '138bc20d02dcc2d8',
#  '138oz',
#  '139',
#  '1399',
#  '13cm',
#  '13ft',
#  '13h',
#  '13h30',
#  '13hrs',
#  '13ish',
#  '13k',
#  '13mins',
#  '13mo',
#  '13month',
#  '13oz',
#  '13pm',
#  '13pp',
#  '13st',
#  '13th',
#  '13u',
#  '13uhr',
#  '13w',
#  '13w4d',
#  '13y',
#  '13yr',
#  '13yrs',
#  '14',
#  '140',
#  '1400',
#  '14000',
#  '1400172',
#  '1401',
#  '1401746274',
#  '1403',
#  '1409',
#  '140degrees',
#  '140ish',
#  '140m',
#  '140pm',
#  '140s',
#  '141',
#  '142',
#  '1421432460623',
#  '14267',
#  '1427',
#  '1429',
#  '143',
#  '1430',
#  '143039295',
#  '143k',
#  '144',
#  '1444',
#  '145',
#  '1450',
#  '14500',
#  '1455',
#  '145lb',
#  '145pm',
#  '146',
#  '146227',
#  '1464',
#  '1464595',
#  '1465',
#  '146636445353948',
#  '1467',
#  '147',
#  '1470',
#  '1475',
#  '1476',
#  '1477',
#  '148',
#  '1480',
#  '1485',
#  '1489',
#  '148oz',
#  '149',
#  '1492',
#  '1495',
#  '14am',
#  '14bucks',
#  '14day',
#  '14days',
#  '14degrees',
#  '14ft',
#  '14g',
#  '14h',
#  '14inch',
#  '14ish',
#  '14k',
#  '14kt',
#  '14mile',
#  '14million',
#  '14min',
#  '14mins',
#  '14mo',
#  '14month',
#  '14oz',
#  '14pm',
#  '14ppl',
#  '14pt',
#  '14s',
#  '14th',
#  '14this',
#  '14times',
#  '14w',
#  '14wks',
#  '14yo',
#  '14yr',
#  '15',
#  '150',
#  '1500',
#  '15000',
#  '150000',
#  '15000w',
#  '1500km',
#  '1500lbs',
#  '1500s',
#  '1504',
#  '150a',
#  '150c',
#  '150cc',
#  '150dollars',
#  '150f',
#  '150g',
#  '150ish',
#  '150k',
#  '150kg',
#  '150lbs',
#  '150mbps',
#  '150pm',
#  '150s',
#  '150th',
#  '150w',
#  '151',
#  '1511',
#  '1516',
#  '152',
#  '1520',
#  '15210',
#  '1525',
#  '152567861509170',
#  '1528',
#  '153',
#  '1530',
#  '15300555',
#  '15369',
#  '1538',
#  '154',
#  '1542',
#  '15440',
#  '1545',
#  '1549',
#  '154lbs',
#  '155',
#  '1550',
#  '1552',
#  '1554',
#  '156',
#  '157',
#  '158',
#  '1582',
#  '15857aaa06f2',
#  '159',
#  '1590',
#  '1594063',
#  '1595',
#  '15a',
#  '15am',
#  '15cad',
#  '15cm',
#  '15cmonth',
#  '15days',
#  '15dollar',
#  '15eur',
#  '15feet',
#  '15for',
#  '15ft',
#  '15h',
#  '15h30',
#  '15hr',
#  '15hrs',
#  '15ish',
#  '15jul14',
#  '15k',
#  '15km',
#  '15kms',
#  '15l',
#  '15lb',
#  '15lbs',
#  '15m',
#  '15mbs',
#  '15miles',
#  '15min',
#  '15mind',
#  '15mins',
#  '15mintues',
#  '15minutes',
#  '15miutes',
#  '15ml',
#  '15mm',
#  '15mn',
#  '15mo',
#  '15more',
#  ...]

# %% [markdown]
# Create a function that takes a single row of the tf-idf matrix (corresponding to a particular document), and return the n highest scoring words (or more generally tokens or features):

# %%
def top_tfidf_feats(row, features, top_n=25):
    ''' Get top n tfidf values in row and return them with their corresponding feature names.'''
    topn_ids = np.argsort(row)[::-1][:top_n]
    top_feats = [(features[i], row[i]) for i in topn_ids]
    df = pd.DataFrame(top_feats)
    df.columns = ['feature', 'tfidf']
    return df

# %% [markdown]
# The result of a tf-idf is a sparse matrix, which doesn’t support all the usual matrix or array operations. So in order to apply the above function to inspect a particular document, we convert a single row into dense format first:

# %%
def top_feats_in_doc(Xtr, features, row_id, top_n=25):
    ''' Top tfidf features in specific document (matrix row) '''
    row = np.squeeze(Xtr[row_id].toarray())
    return top_tfidf_feats(row, features, top_n)

# %%
len(trainDf.loc[trainDf['active']==1])
# Out:
# 168457

# %%
trainDf.iloc[168456]
# Out:
# business_id                               xmARZ_MuSfrQCXP4e8RQjg
# date                                                  2013-03-03
# review_id                                 DbTzR3TDySXvYjZRWCO10g
# stars                                                          3
# text           I want to be able to give Nello's 3.5 stars. \...
# user_id                                   BuwzRmdVk0uu17qG49l37A
# active                                                         1
# Name: 291321, dtype: object

# %%
trainDf.iloc[168457]
# Out:
# business_id                               Eif660dJb3nqORM6LF3UYg
# date                                                  2015-12-07
# review_id                                 a6wkURhUcsDihsNqv0p8LQ
# stars                                                          1
# text           I was forced by the app to give it a star. Jus...
# user_id                                   m44kwkYYFTOMpQM1DeIg4w
# active                                                         0
# Name: 52298, dtype: object

# %% [markdown]
# Due to the way I constructed the train data, *the active users are stored in the first 168457 rows in the trainDf, and the rows are all reviews that belong to inactive users.*
#
# Try using top_feats_in_doc to find the top 10 most important words for the active user on row 0, and those for the active user on row 4.

# %%
top_feats_in_doc(X_train_tfidf,features,0,10)
# Out:
#        feature     tfidf
# 0       yellow  0.230024
# 1         dahl  0.221549
# 2         whey  0.203711
# 3        curry  0.189788
# 4     hungover  0.179498
# 5       herbal  0.172362
# 6      sautéed  0.163888
# 7       thinly  0.159444
# 8  scrumptious  0.155432
# 9       triple  0.151808

# %%
top_feats_in_doc(X_train_tfidf,features,4,10)
# Out:
#     feature     tfidf
# 0     crepe  0.506723
# 1  aromatic  0.365277
# 2     sweet  0.291273
# 3     latte  0.275677
# 4    overly  0.252598
# 5      cafe  0.233309
# 6    potato  0.224764
# 7      cute  0.221078
# 8      okay  0.203687
# 9       big  0.163168

# %% [markdown]
# It would be nice if I can have the top features(important words) summarized for all active users, and all inactive users, so we create a function that returns the top n important words that are on average most importnatn among all reviews identified by indices in grp_ids.
# Because common words such as 'the', while having low tf-idf scores within each review, are so frequent that when averaged over all reviews they would easily dominate all other terms, so we need to filter our the words with relatively low scores.

# %%
def top_mean_feats(Xtr, features, grp_ids, min_tfidf=0.1, top_n=25):
    ''' Return a data frame of the top n features that on average are most important amongst documents in rows
        identified by indices in grp_ids. '''
    D = Xtr[grp_ids].toarray()
    D = Xtr.toarray()
    D[D < min_tfidf] = 0
    tfidf_means = np.mean(D, axis=0)
    return top_tfidf_feats(tfidf_means, features, top_n)

# %%
X_train_tfidf
# Out:
# <339700x180431 sparse matrix of type '<class 'numpy.float64'>'
# 	with 26478750 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Due to the limitation of my laptop's memory, I can only run top_mean_feats for a subset of the users.

# %%
activeFeatsDf=top_mean_feats(X_train_tfidf,features, slice(0,5000))

# %% [markdown]
# Running the code above makes my laptop crashes, but it works if I don't run it in separate commands instead of using one single function.

# %%
D=X_train_tfidf[:5000].toarray()

# %%
D[D < 0.1] = 0

# %%
tfidf_means = np.mean(D, axis=0)

# %%
activeFeatsDf=top_tfidf_feats(tfidf_means, features, 50)

# %%
activeFeatsDf
# Out:
#       feature     tfidf
# 0     chicken  0.006611
# 1          we  0.006401
# 2      always  0.006118
# 3       pizza  0.005761
# 4       lunch  0.005708
# 5         was  0.005382
# 6    location  0.005242
# 7        good  0.005207
# 8       sushi  0.005145
# 9      burger  0.005068
# 10       food  0.004864
# 11      great  0.004844
# 12       love  0.004711
# 13      their  0.004654
# 14   sandwich  0.004604
# 15         is  0.004597
# 16      fries  0.004576
# 17        you  0.004540
# 18       soup  0.004366
# 19       nice  0.004350
# 20     really  0.004262
# 21     pretty  0.004240
# 22      place  0.004232
# 23      store  0.004220
# 24        the  0.004203
# 25       here  0.004095
# 26        bar  0.004085
# 27       rice  0.004006
# 28     coffee  0.003997
# 29  breakfast  0.003914
# 30        are  0.003902
# 31      fresh  0.003895
# 32  selection  0.003763
# 33  delicious  0.003733
# 34     little  0.003711
# 35         as  0.003688
# 36        its  0.003675
# 37      salad  0.003669
# 38       fish  0.003661
# 39       pork  0.003653
# 40        she  0.003648
# 41     cheese  0.003570
# 42       fast  0.003564
# 43        tea  0.003557
# 44       meat  0.003550
# 45        ice  0.003472
# 46     prices  0.003426
# 47       very  0.003422
# 48      spicy  0.003401
# 49       beer  0.003393

# %%
D=X_train_tfidf[-5000:].toarray()

# %%
D[D < 0.1] = 0

# %%
tfidf_means = np.mean(D, axis=0)

# %%
inactiveFeatsDf=top_tfidf_feats(tfidf_means, features, 50)

# %%
inactiveFeatsDf
# Out:
#          feature     tfidf
# 0          great  0.014699
# 1             we  0.013122
# 2           food  0.012076
# 3            she  0.010914
# 4             he  0.010662
# 5        service  0.010655
# 6            was  0.010122
# 7           very  0.009971
# 8           best  0.009592
# 9        amazing  0.009336
# 10           the  0.009324
# 11         staff  0.008718
# 12      friendly  0.008668
# 13           our  0.008530
# 14     recommend  0.008427
# 15        highly  0.007643
# 16         place  0.007634
# 17          love  0.007579
# 18           her  0.007570
# 19       awesome  0.007326
# 20    definitely  0.007274
# 21      customer  0.006783
# 22            is  0.006684
# 23     excellent  0.006578
# 24          good  0.006522
# 25            us  0.006400
# 26          will  0.006385
# 27        always  0.006359
# 28          ever  0.006271
# 29  professional  0.006256
# 30           job  0.006079
# 31           you  0.005937
# 32         again  0.005761
# 33           and  0.005751
# 34          hair  0.005642
# 35           car  0.005579
# 36          nice  0.005578
# 37         pizza  0.005568
# 38          were  0.005559
# 39          back  0.005508
# 40          they  0.005432
# 41           his  0.005342
# 42     delicious  0.005338
# 43       helpful  0.005149
# 44          work  0.005121
# 45          time  0.005087
# 46        really  0.005038
# 47         vegas  0.004990
# 48    experience  0.004982
# 49    restaurant  0.004978

# %%
# Tells matplotlib to display images inline instead of a new window
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
activeFeatsDf.label="active"
inactiveFeatsDf.label="inactive"

# %%
def plot_tfidf_classfeats_h(dfs):
    ''' Plot the data frames of different classes returned by the function top_mean_feats(). '''
    fig = plt.figure(figsize=(12, 9), facecolor="w")
    x = np.arange(len(dfs[0]))
    for i, df in enumerate(dfs):
        ax = fig.add_subplot(1, len(dfs), i+1)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.set_frame_on(False)
        ax.get_xaxis().tick_bottom()
        ax.get_yaxis().tick_left()
        ax.set_xlabel("Mean Tf-Idf Score", labelpad=16, fontsize=14)
        ax.set_title("label = " + str(df.label), fontsize=16)
        ax.ticklabel_format(axis='x', style='sci', scilimits=(-2,2))
        ax.barh(x, df.tfidf, align='center', color='#3F5D7D')
        ax.set_yticks(x)
        ax.set_ylim([-1, x[-1]+1])
        yticks = ax.set_yticklabels(df.feature)
        plt.subplots_adjust(bottom=0.09, right=0.97, left=0.15, top=0.95, wspace=0.52)
    plt.show()

# %% [markdown]
# ## Visualize tf-idf scores of the most important words among active users and inactive users respectively
# Active users talk about chicken, pizza, sushi, purher, and sandwich a lot, werhe as inactive users don't talk about specific food that much, but care more about service and vibe. Inactive users also tend to use more generic words like excenllent, awesome, great, nice, amazing, etc.

# %%
plot_tfidf_classfeats_h([activeFeatsDf,inactiveFeatsDf])

# %% [markdown]
# ## Visualize SVM (in progress)
# I attempt to visualize the tf-idf matrix and the performance of the SVM model using PCA to do row reduction, but again, the kernel crashes.
# Rerence: https://stackoverflow.com/questions/28160335/plot-a-document-tfidf-2d-graph

# %%
from sklearn.decomposition import PCA
X=X_train_tfidf.todense()
pca = PCA(n_components=2).fit(X)
